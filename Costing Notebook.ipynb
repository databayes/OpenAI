# %% [markdown]
# """
# ### 💸 Azure
# Azure OpenAI costs are based on the **tokens used**, **model deployed**, and **region**. Here's how it works:
#
# #### 🧮 1. **Cost Components**
# - **Model**: Each model (e.g. `gpt-4`, `gpt-4o`, `gpt-35-turbo`) has a different per-token price.
# - **Tokens**: You are billed per 1,000 tokens (both prompt + completion).
# - **Deployment**: Each deployed model can have separate configurations, but pricing is **per usage**, not for just having a deployment.
#
# #### 📦 2. **Token Types**
# - **Prompt tokens**: Input you send to the model.
# - **Completion tokens**: Output generated by the model.
# - You pay for **both**, rounded to the nearest 1,000 tokens.
#
# #### 💰 3. **Example Pricing (as of June 2025)**
# | Model              | Prompt (per 1,000 tokens) | Completion (per 1,000 tokens) |
# |--------------------|---------------------------|--------------------------------|
# | `gpt-4o`           | $5.00                     | $15.00                         |
# | `gpt-4`            | $10.00                    | $30.00                         |
# | `gpt-35-turbo`     | $0.0015                   | $0.002                         |
#
# > 💡 Prices may vary slightly by Azure region. Always check the [official Azure OpenAI pricing page](https://azure.microsoft.com/en-us/pricing/details/cognitive-services/openai-service/).
#
# #### 🧾 4. **Monthly Cost Estimation Formula**
# ```
# Monthly Cost ≈ (Prompt tokens + Completion tokens) / 1000 × Unit price
# ```
#
# #### 🧪 5. **Monitoring Usage**
# - Use Azure Metrics or Quotas page in the portal.
# - Or track `X-Token-Usage` from API responses for real-time logging.
#
# ---
#
# ### ✅ Tips
# - Use `gpt-35-turbo` for lightweight tasks to save cost.
# - Monitor token usage early when building apps.
# - Use `max_tokens` and `temperature` to control length and variability.
# """
